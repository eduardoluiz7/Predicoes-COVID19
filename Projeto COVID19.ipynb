# %% [markdown]
# # Prevendo crescimento do número de casos de COVID-19 no Brasil usando Inteligência Artificial

# %% [markdown]
# ## Preparando os dados

# %%
import pandas as pd
import numpy as np

# %%
casosBrasil = pd.read_csv('https://brasil.io/dataset/covid19/caso/?format=csv')
casosBrasil.head()
# Out:
#          date state              city place_type  confirmed  deaths  is_last  \
# 0  2020-06-03    SP        Adamantina       city         43       3     True
# 1  2020-06-03    SP            Adolfo       city          3       0     True
# 2  2020-06-03    SP             Aguaí       city         38       3     True
# 3  2020-06-03    SP    Águas da Prata       city          1       0     True
# 4  2020-06-03    SP  Águas de Lindóia       city         16       1     True
#
#    estimated_population_2019  city_ibge_code  confirmed_per_100k_inhabitants  \
# 0                    35068.0       3500105.0                       122.61891
# 1                     3562.0       3500204.0                        84.22235
# 2                    36305.0       3500303.0                       104.66878
# 3                     8180.0       3500402.0                        12.22494
# 4                    18705.0       3500501.0                        85.53863
#
#    death_rate
# 0      0.0698
# 1      0.0000
# 2      0.0789
# 3      0.0000
# 4      0.0625

# %%
# excluindo colunas desnecessárias
casosBR = casosBrasil.drop(['place_type', 'deaths','estimated_population_2019', 'city_ibge_code', 'death_rate', 'confirmed_per_100k_inhabitants', 'is_last'], axis=1)
casosBR.head()
# Out:
#          date state              city  confirmed
# 0  2020-06-03    SP        Adamantina         43
# 1  2020-06-03    SP            Adolfo          3
# 2  2020-06-03    SP             Aguaí         38
# 3  2020-06-03    SP    Águas da Prata          1
# 4  2020-06-03    SP  Águas de Lindóia         16

# %%
# pegando apenas dados dos estados
casosEstados = casosBR[casosBR['city'].isnull()]

# %%
casosEstados = casosEstados.drop('city', axis=1)
casosEstados = casosEstados.sort_values(by=['date'])
casosEstados
# Out:
#               date state  confirmed
# 151897  2020-02-25    SP          1
# 151895  2020-02-26    SP          1
# 151893  2020-02-27    SP          1
# 151891  2020-02-28    SP          2
# 151889  2020-02-29    SP          2
# ...            ...   ...        ...
# 3471    2020-06-02    SC       9660
# 3547    2020-06-02    SE       7555
# 4094    2020-06-02    SP     118295
# 2194    2020-06-02    MG      10939
# 550     2020-06-03    SP     123483
#
# [2140 rows x 3 columns]

# %%
# Agrupando o número de casos de acordo com estados e as datas
casosEstados = casosEstados.groupby(['state', 'date']).pipe(lambda x: x.confirmed.sum()).unstack().fillna(0)

# %%
# Convertendo valores para inteiro
cols = list(casosEstados)
for col in cols:
    casosEstados[col] = pd.to_numeric(casosEstados[col], downcast='integer')

# %%
casosEstados.head()
# Out:
# date   2020-02-25  2020-02-26  2020-02-27  2020-02-28  2020-02-29  2020-03-01  \
# state
# AC              0           0           0           0           0           0
# AL              0           0           0           0           0           0
# AM              0           0           0           0           0           0
# AP              0           0           0           0           0           0
# BA              0           0           0           0           0           0
#
# date   2020-03-02  2020-03-03  2020-03-04  2020-03-05  ...  2020-05-25  \
# state                                                  ...
# AC              0           0           0           0  ...        4501
# AL              0           0           0           0  ...        6682
# AM              0           0           0           0  ...       30282
# AP              0           0           0           0  ...        6584
# BA              0           0           0           0  ...       14204
#
# date   2020-05-26  2020-05-27  2020-05-28  2020-05-29  2020-05-30  2020-05-31  \
# state
# AC           4781        5251        5600        5841        6072        6219
# AL           7058        7580        8056        8619        9223       10288
# AM          31949       33508       36146       38909       40560       41378
# AP           6967        7619        8152        8469        9313        9602
# BA          14566       15070       15963       16917       17626       18392
#
# date   2020-06-01  2020-06-02  2020-06-03
# state
# AC           6326        6465           0
# AL          10837       11559           0
# AM          41774       43195           0
# AP           9890       10511           0
# BA          18898       21430           0
#
# [5 rows x 100 columns]

# %%
dias = list(casosEstados)
print(dias)
# Out:
# ['2020-02-25', '2020-02-26', '2020-02-27', '2020-02-28', '2020-02-29', '2020-03-01', '2020-03-02', '2020-03-03', '2020-03-04', '2020-03-05', '2020-03-06', '2020-03-07', '2020-03-08', '2020-03-09', '2020-03-10', '2020-03-11', '2020-03-12', '2020-03-13', '2020-03-14', '2020-03-15', '2020-03-16', '2020-03-17', '2020-03-18', '2020-03-19', '2020-03-20', '2020-03-21', '2020-03-22', '2020-03-23', '2020-03-24', '2020-03-25', '2020-03-26', '2020-03-27', '2020-03-28', '2020-03-29', '2020-03-30', '2020-03-31', '2020-04-01', '2020-04-02', '2020-04-03', '2020-04-04', '2020-04-05', '2020-04-06', '2020-04-07', '2020-04-08', '2020-04-09', '2020-04-10', '2020-04-11', '2020-04-12', '2020-04-13', '2020-04-14', '2020-04-15', '2020-04-16', '2020-04-17', '2020-04-18', '2020-04-19', '2020-04-20', '2020-04-21', '2020-04-22', '2020-04-23', '2020-04-24', '2020-04-25', '2020-04-26', '2020-04-27', '2020-04-28', '2020-04-29', '2020-04-30', '2020-05-01', '2020-05-02', '2020-05-03', '2020-05-04', '2020-05-05', '2020-05-06', '2020-05-07', '2020-05-08', '2020-05-09', '2020-05-10', '2020-05-11', '2020-05-12', '2020-05-13', '2020-05-14', '2020-05-15', '2020-05-16', '2020-05-17', '2020-05-18', '2020-05-19', '2020-05-20', '2020-05-21', '2020-05-22', '2020-05-23', '2020-05-24', '2020-05-25', '2020-05-26', '2020-05-27', '2020-05-28', '2020-05-29', '2020-05-30', '2020-05-31', '2020-06-01', '2020-06-02', '2020-06-03']

# %%
for estado in casosEstados.iterrows():
    for i in range(1, len(dias)):
        a = dias[i]
        b = dias[i-1]
        if casosEstados.loc[estado[0], dias[i]] < casosEstados.loc[estado[0], dias[i-1]]:
            casosEstados.loc[estado[0], dias[i]] = casosEstados.loc[estado[0], dias[i-1]]

# %%
casosEstados.head()
# Out:
# date   2020-02-25  2020-02-26  2020-02-27  2020-02-28  2020-02-29  2020-03-01  \
# state
# AC              0           0           0           0           0           0
# AL              0           0           0           0           0           0
# AM              0           0           0           0           0           0
# AP              0           0           0           0           0           0
# BA              0           0           0           0           0           0
#
# date   2020-03-02  2020-03-03  2020-03-04  2020-03-05  ...  2020-05-25  \
# state                                                  ...
# AC              0           0           0           0  ...        4501
# AL              0           0           0           0  ...        6682
# AM              0           0           0           0  ...       30282
# AP              0           0           0           0  ...        6584
# BA              0           0           0           0  ...       14204
#
# date   2020-05-26  2020-05-27  2020-05-28  2020-05-29  2020-05-30  2020-05-31  \
# state
# AC           4781        5251        5600        5841        6072        6219
# AL           7058        7580        8056        8619        9223       10288
# AM          31949       33508       36146       38909       40560       41378
# AP           6967        7619        8152        8469        9313        9602
# BA          14566       15070       15963       16917       17626       18392
#
# date   2020-06-01  2020-06-02  2020-06-03
# state
# AC           6326        6465        6465
# AL          10837       11559       11559
# AM          41774       43195       43195
# AP           9890       10511       10511
# BA          18898       21430       21430
#
# [5 rows x 100 columns]

# %%
# primeiro dia de casos até dia 01/06
x_train = np.array(casosEstados.loc[:,dias[:len(dias)-2]])
print(x_train)
# dia 02/06
y_train = np.array(casosEstados[dias[-2]])
print(y_train)
# do segundo dia de casos até dia 02/06
x_test = casosEstados[dias[1:-1]]
# dia 03/06
y_test = np.array(casosEstados[dias[-1]])
# Out:
# [[     0      0      0 ...   6072   6219   6326]
#  [     0      0      0 ...   9223  10288  10837]
#  [     0      0      0 ...  40560  41378  41774]
#  ...
#  [     0      0      0 ...   6805   6999   7233]
#  [     1      1      1 ... 107142 109698 111296]
#  [     0      0      0 ...   3981   4176   4345]]
# [  6465  11559  43195  10511  21430  54683  11256  15151   4486  38174
#   10939   1646   2817  43652  13695  35508   5828   4900  56732   8233
#    5477   3692   9919   9660   7555 118295   4345]

# %% [markdown]
# ## Regressão Linear

# %%
# importando modelo de regressão linear e a métrica r2_score
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# %%
linear_regression = LinearRegression()

# %%
linear_regression.fit(x_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
# realizando predição do dia 03/06
y_pred = linear_regression.predict(x_test)

# %%
# erro percentual
rmspe = (np.sqrt(np.mean(np.square((y_test - y_pred) / y_test)))) * 100
rmspe
# Out:
# 7.5763455793825045

# %%
r2 = r2_score(y_test, y_pred)
r2
# Out:
# 0.9947922175235921

# %%
linear_regression.score(x_train, y_pred)
# Out:
# 0.9938322516222711

# %% [markdown]
# ## SVR Linear

# %%
# importando SVR
from sklearn.svm import SVR

# %%
svr = SVR(kernel='linear', C=0.1)

# %%
svr.fit(x_train, y_train)
# Out:
# SVR(C=0.1, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='scale',
#     kernel='linear', max_iter=-1, shrinking=True, tol=0.001, verbose=False)

# %%
y_pred=svr.predict(x_test)

# %%
# erro percentual
rmspe = (np.sqrt(np.mean(np.square((y_test - y_pred) / y_test)))) * 100
rmspe
# Out:
# 7.594874725748417

# %%
r2 = r2_score(y_test, y_pred)
r2
# Out:
# 0.9947655679077078

# %% [markdown]
# ## Prevendo número de casos do dia 04/06
# Usando regressão linear pois teve resultados melhores

# %%
x = casosEstados[dias[2:]]
y_pred = linear_regression.predict(x)
y_pred = y_pred.astype('int')
# Out:
# array([  6354.91025945,  11421.42518865,  41223.72944179,  12056.95453123,
#         20272.99588061,  57118.85708576,  11260.42279324,  14966.87284462,
#          4451.94030002,  40042.79039252,  10292.59368748,   1730.7333819 ,
#          2882.31082648,  44863.63651332,  13606.13376078,  40020.90677981,
#          5498.13687494,   4359.63783931,  60059.58097638,   5986.24269029,
#          4974.60685481,   3746.68342389,   9103.12332647,   8009.56356951,
#          7345.5683082 , 115947.89886786,   3664.09821137])

# %%
casosEstados['2020-06-04'] = y_pred
casosEstados
# Out:
# date   2020-02-25  2020-02-26  2020-02-27  2020-02-28  2020-02-29  2020-03-01  \
# state
# AC              0           0           0           0           0           0
# AL              0           0           0           0           0           0
# AM              0           0           0           0           0           0
# AP              0           0           0           0           0           0
# BA              0           0           0           0           0           0
# CE              0           0           0           0           0           0
# DF              0           0           0           0           0           0
# ES              0           0           0           0           0           0
# GO              0           0           0           0           0           0
# MA              0           0           0           0           0           0
# MG              0           0           0           0           0           0
# MS              0           0           0           0           0           0
# MT              0           0           0           0           0           0
# PA              0           0           0           0           0           0
# PB              0           0           0           0           0           0
# PE              0           0           0           0           0           0
# PI              0           0           0           0           0           0
# PR              0           0           0           0           0           0
# RJ              0           0           0           0           0           0
# RN              0           0           0           0           0           0
# RO              0           0           0           0           0           0
# RR              0           0           0           0           0           0
# RS              0           0           0           0           0           0
# SC              0           0           0           0           0           0
# SE              0           0           0           0           0           0
# SP              1           1           1           2           2           2
# TO              0           0           0           0           0           0
#
# date   2020-03-02  2020-03-03  2020-03-04  2020-03-05  ...  2020-05-26  \
# state                                                  ...
# AC              0           0           0           0  ...        4781
# AL              0           0           0           0  ...        7058
# AM              0           0           0           0  ...       31949
# AP              0           0           0           0  ...        6967
# BA              0           0           0           0  ...       14566
# CE              0           0           0           0  ...       37021
# DF              0           0           0           0  ...        7210
# ES              0           0           0           1  ...       10889
# GO              0           0           0           0  ...        2706
# MA              0           0           0           0  ...       26145
# MG              0           0           0           0  ...        7516
# MS              0           0           0           0  ...        1186
# MT              0           0           0           0  ...        1744
# PA              0           0           0           0  ...       29882
# PB              0           0           0           0  ...        8919
# PE              0           0           0           0  ...       28854
# PI              0           0           0           0  ...        3966
# PR              0           0           0           0  ...        3567
# RJ              0           0           0           1  ...       40024
# RN              0           0           0           0  ...        5630
# RO              0           0           0           0  ...        3493
# RR              0           0           0           0  ...        2682
# RS              0           0           0           0  ...        6785
# SC              0           0           0           0  ...        7016
# SE              0           0           0           0  ...        5735
# SP              2           2           3           6  ...       86017
# TO              0           0           0           0  ...        2858
#
# date   2020-05-27  2020-05-28  2020-05-29  2020-05-30  2020-05-31  2020-06-01  \
# state
# AC           5251        5600        5841        6072        6219        6326
# AL           7580        8056        8619        9223       10288       10837
# AM          33508       36146       38909       40560       41378       41774
# AP           7619        8152        8469        9313        9602        9890
# BA          15070       15963       16917       17626       18392       18898
# CE          37275       37821       38395       47822       48489       50504
# DF           7761        8300        8722        9474        9780       10510
# ES          11484       12203       12903       12903       13690       13690
# GO           2906        3101        3521        3609        3726        4017
# MA          27979       30482       32620       34639       35297       36625
# MG           8011        8686        9232        9630       10464       10670
# MS           1262        1356        1418        1489        1568        1646
# MT           1909        2085        2262        2413        2485        2636
# PA          31671       35132       37296       37859       37961       40014
# PB          10209       11132       12011       12862       13162       13695
# PE          29919       30713       32255       33427       34450       34900
# PI           4243        4503        4745        4931        5119        5506
# PR           3768        4041        4300        4538        4752        4900
# RJ          42398       44886       47953       52420       53388       54530
# RN           5630        6463        7402        7402        8008        8233
# RO           3862        4252        4502        4743        4942        4942
# RR           2959        3098        3299        3474        3692        3692
# RS           7048        8234        8843        9242        9332        9496
# SC           7372        8000        8530        8780        9037        9498
# SE           5912        6156        6462        6805        6999        7233
# SP          89483       95865      101556      107142      109698      111296
# TO           2858        3277        3611        3981        4176        4345
#
# date   2020-06-02  2020-06-03  2020-06-04
# state
# AC           6465        6465        6354
# AL          11559       11559       11421
# AM          43195       43195       41223
# AP          10511       10511       12056
# BA          21430       21430       20272
# CE          54683       54683       57118
# DF          11256       11256       11260
# ES          15151       15151       14966
# GO           4486        4486        4451
# MA          38174       38174       40042
# MG          10939       10939       10292
# MS           1646        1646        1730
# MT           2817        2817        2882
# PA          43652       43652       44863
# PB          13695       13695       13606
# PE          35508       35508       40020
# PI           5828        5828        5498
# PR           4900        4900        4359
# RJ          56732       56732       60059
# RN           8233        8233        5986
# RO           5477        5477        4974
# RR           3692        3692        3746
# RS           9919        9919        9103
# SC           9660        9660        8009
# SE           7555        7555        7345
# SP         118295      123483      115947
# TO           4345        4345        3664
#
# [27 rows x 101 columns]
